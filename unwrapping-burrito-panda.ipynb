# %%
import pandas as pd
import numpy as np
import pickle
df = pickle.load(open('clean-burrito-pandas.pkl', 'rb'))

# %%
features = ['Chips_1h',
 'Beef_1h',
 'Pico_1h',
 'Guac_1h',
 'Cheese_1h',
 'Fries_1h',
 'Sour cream_1h',
 'Pork_1h',
 'Chicken_1h',
 'Shrimp_1h',
 'Fish_1h',
 'Rice_1h',
 'Beans_1h',
 'Lettuce_1h',
 'Tomato_1h',
 'Bell peper_1h',
 'Carrots_1h',
 'Cabbage_1h',
 'Sauce_1h',
 'Salsa.1_1h',
 'Cilantro_1h',
 'Onion_1h',
 'Taquito_1h',
 'Pineapple_1h',
 'Ham_1h',
 'Chile relleno_1h',
 'Nopales_1h',
 'Lobster_1h',
 'Queso_1h',
 'Egg_1h',
 'Mushroom_1h',
 'Bacon_1h',
 'Sushi_1h',
 'Avocado_1h',
 'Corn_1h',
 'Zucchini_1h',
 'Cost',
 'Yelp',
 'Google']

# %%
query = 100

# %%
burrito_idx = query
burrito_vendor = df.iloc[query][0]
burrito_type = df.iloc[query][1]
burrito_yelp = df.iloc[query][6]
burrito_google = df.iloc[query][7]
burrito_cost = df.iloc[query][8]

# %%
title = f"#{burrito_idx}, {burrito_type} Burrito from {burrito_vendor}(${burrito_cost})"

# %%
title
# Out:
# "#100, Bomb Burrito from Karina's Taco Shop ($8)"

# %%
for idx, row in df.iterrows():
    print(idx)
    print(row[0])
    print(row[1])
# Out:
# 0
# Donato's taco shop
# California
# 1
# Oscar's Mexican food
# California
# 2
# Oscar's Mexican food
# Carnitas
# 3
# Oscar's Mexican food
# Carne asada
# 4
# Pollos Maria
# California
# 5
# Pollos Maria
# combo chicken
# 6
# Nico's Taco Shop
# California
# 7
# Nico's Taco Shop
# Carnitas
# 8
# Los Primos Mexican Food
# Monster California
# 9
# JV's Mexican Food
# Carne Asada
# 10
# JV's Mexican Food
# Surf & Turf
# 11
# Tony's Fresh Mexican Food
# Chile verde pork
# 12
# Tony's Fresh Mexican Food
# California
# 13
# Tony's Fresh Mexican Food
# battered fish
# 14
# Tony's Fresh Mexican Food
# California
# 15
# Taco Stand
# California
# 16
# Taco Stand
# Surf and turf
# 17
# Graciela's Taco Shop
# Adobada
# 18
# Graciela's Taco Shop
# Barbacoa
# 19
# Rigoberto's Taco Shop La Jolla
# California
# 20
# Rigoberto's Taco Shop La Jolla
# California
# 21
# Lolita's taco shop
# 2 in 1
# 22
# Lolita's taco shop
# Adobado
# 23
# Taco Stand
# California
# 24
# Taco Stand
# California
# 25
# ...
